# %%
import pandas as pd

df_batedores =  pd.read_csv("Dados_tratados_-_Batedores_2026.xlsx - GERAL.csv", usecols=[8, 97,98,100,101,102,103,104,105,106,109,110,111,112])
df_batedores.head(10)
# Out:
#                                           Unnamed: 8  \
# 0  3. De quem você compra o fruto que você processa?
# 1                              Feiras/portos de açaí
# 2                                     Atravessadores
# 3                             Extrativistas/famílias
# 4                             Extrativistas/famílias
# 5                                     Atravessadores
# 6                             Extrativistas/famílias
# 7                                     Atravessadores
# 8                                     Atravessadores
# 9                              Feiras/portos de açaí
#
#                                          Unnamed: 97       Unnamed: 98  \
# 0  18. Onde você deposita os caroços de açaí temp...  18. Outro. Qual?
# 1                Na via pública (na calçada, na rua)               NaN
# 2                Na via pública (na calçada, na rua)               NaN
# 3                         Área privada para esse fim               NaN
# ...

# %%
df_coletores = pd.read_csv("Dados_tratados_-_Coletores_2026.xlsx - Geral.csv", usecols=[20,30,31,43,44,45,46])
df_coletores.head(10) ########
# Out:
#    4. Quais são os seus principais pontos de coleta?  \
# 0     Batedores / Vitaminosas Cooperativa/associação
# 1  Batedores / Vitaminosas Via pública e entorno ...
# 2                            Batedores / Vitaminosas
# 3                            Batedores / Vitaminosas
# 4                            Batedores / Vitaminosas
# 5                               Indústrias/ empresas
# 6       Batedores / Vitaminosas Indústrias/ empresas
# 7                               Indústrias/ empresas
# 8  Batedores / Vitaminosas Via pública e entorno ...
# 9       Indústrias/ empresas Batedores / Vitaminosas
#
#   6. Qual o destino do caroço de açaí que você coleta?  \
# 0                               Entrega para empresa
# 1                               Entrega para empresa
# 2                   Aproveito para adubo/compostagem
# 3                               Entrega para empresa
# 4                               Entrega para empresa
# 5                               Entrega para empresa
# ...
